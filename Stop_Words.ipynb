# %%
import spacy

nlp = spacy.load('en_core_web_sm')

# %%
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
# checking if a word is stop word or not

print(nlp.vocab['check'].is_stop)
print(nlp.vocab['is'].is_stop)
# Out:
# False
# True

# %%
# add words to stop word set
print(nlp.vocab['btw'].is_stop)

nlp.vocab['btw'].is_stop = True
print(len(nlp.Defaults.stop_words))
print(nlp.vocab['btw'].is_stop)

nlp.Defaults.stop_words.add('btw')
print(len(nlp.Defaults.stop_words))
print(nlp.vocab['btw'].is_stop)
# Out:
# False
# 327
# True
# 327
# True

# %%
# We can also use remove to remove any word from the stop word list
